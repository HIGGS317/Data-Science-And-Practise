# %% [markdown]
# ## Excercise 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
plt.plot([1, 2, 4, 5], [1, 3, 4, 3], '-o')

# %% [markdown]
# ## Excercise 2

# %%
list_of_names = ['GOOGL_data','FB_data','AAPL_data','AMZN_data','MSFT_data']

dataframes_list = []
for i in range(len(list_of_names)):
    temp_df = pd.read_csv("./Activity 8 (15 Oct 2022)/Datasets/"+list_of_names[i]+".csv")
    dataframes_list.append(temp_df)

# %%
plt.figure(figsize = (16,5))
for i in range(len(dataframes_list)):
    plt.plot(dataframes_list[i]['date'],dataframes_list[i]['close'],label = list_of_names[i])

plt.grid()
plt.legend()
plt.title('Stocks Trend')
plt.ylabel('Closing Price in $')
# Out:
# Text(0, 0.5, 'Closing Price in $')

# %% [markdown]
# ## Excercise 3

# %%
movie = pd.read_csv("./Activity 8 (15 Oct 2022)/Datasets/movie_scores.csv")

# %%
plt.figure(figsize = (16,10))
label = []
for i in range(len(movie)):
    label.append(movie['MovieTitle'][i])

x = np.arange(len(label))
width = 0.4

plt.bar(x,movie['Tomatometer'],width=width)
plt.bar(x+width,movie['AudienceScore'],width=width)
plt.xticks(x+width/2,(label))
ax = plt.gca()
ax.yaxis.grid(which='major')
ax.yaxis.grid(which='minor',linestyle = '--')
plt.legend(['Tomatometer','AudienceScore'])
plt.title('Movie Comparison')
# Out:
# Text(0.5, 1.0, 'Movie Comparison')

# %% [markdown]
# ## Excercise 4

# %%
water = pd.read_csv("./Activity 8 (15 Oct 2022)/Datasets/water_usage.csv")

# %%
water
# Out:
#    Unnamed: 0           Usage  Percentage
# 0           0            Leak          12
# 1           1  Clothes Washer          17
# 2           2          Faucet          19
# 3           3          Shower          20
# 4           4          Toilet          24
# 5           5           Other           8

# %%
plt.figure(figsize=(4,4), dpi=300)
plt.pie('Percentage', explode=(0, 0,
0.1, 0, 0, 0), \
labels='Usage', data=water,
autopct='%.0f%%')
plt.title('Water usage')
# Out:
# Text(0.5, 1.0, 'Water usage')

# %% [markdown]
# ## Excercise 5

# %%
tip = sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# ## Excercise 6

# %%
phone = pd.read_csv("./Activity 8 (15 Oct 2022)/Datasets/smartphone_sales.csv")
phone
# Out:
#    Unnamed: 0 Quarter  Apple  Samsung  Huawei  Xiaomi   OPPO
# 0           0    3Q16  43001    71734   32490   14926  24591
# 1           1    4Q16  77039    76783   40804   15751  26705
# 2           2    1Q17  51993    78776   34181   12707  30922
# 3           3    2Q17  44315    82855   35964   21179  26093
# 4           4    3Q17  45442    85605   36502   26853  29449
# 5           5    4Q17  73175    74027   43887   28188  25660
# 6           6    1Q18  54059    78565   40426   28498  28173
# 7           7    2Q18  44715    72336   49847   32826  28511

# %%
plt.stackplot(phone['Quarter'],[phone['Apple'],phone['Samsung'],phone['Huawei'],phone['Xiaomi'],phone['OPPO']],labels=['Apple','Samsung','Huawei','Xiaomi','OPPO'])
plt.title('Smartphone Sales Units')
plt.xlabel('QUarters')
plt.ylabel('Sales units in thousands')
plt.legend()

# %% [markdown]
# ## Excercise 7

# %%
iq_scores = [126, 89, 90, 101, 102, 74,
93, 101, 66, \
120, 108, 97, 98, 105, 119,
92, 113, 81, \
104, 108, 83, 102, 105,
111, 102, 107, 103, \
89, 89, 110, 71, 110, 120,
85, 111, 83, 122, \
120, 102, 84, 118, 100,
100, 114, 81, 109, 69, \
97, 95, 106, 116, 109, 114,
98, 90, 92, 98, \
91, 81, 85, 86, 102, 93,
112, 76, 89, 110, \
75, 100, 90, 96, 94, 107,
108, 95, 96, 96, \
114, 93, 95, 117, 141, 115,
95, 86, 100, 121, \
103, 66, 99, 96, 111, 110,
105, 110, 91, 112, \
102, 112, 75]

# %%
from turtle import color


plt.hist(iq_scores,bins=10)
plt.axvline(100,color='red')
plt.axvline(85,color='red',linestyle='--')
plt.axvline(115,color='red',linestyle='--')
plt.xlabel('IQ Score')
plt.ylabel('Frequency')
plt.title('IQ SCores for a test group of a hundred adults')
# Out:
# Text(0.5, 1.0, 'IQ SCores for a test group of a hundred adults')

# %%
plt.boxplot(iq_scores)
plt.xlabel('IQ Score')
plt.ylabel('Frequency')
plt.title('IQ SCores for a test group of a hundred adults')
# Out:
# Text(0.5, 1.0, 'IQ SCores for a test group of a hundred adults')

# %%
group_a = [118, 103, 125, 107, 111, 96,
104, 97, 96, \
114, 96, 75, 114, 107, 87,
117, 117, 114, \
117, 112, 107, 133, 94, 91,
118, 110, 117, \
86, 143, 83, 106, 86, 98,
126, 109, 91, 112, \
120, 108, 111, 107, 98, 89,
113, 117, 81, 113, \
112, 84, 115, 96, 93, 128,
115, 138, 121, 87, \
112, 110, 79, 100, 84, 115,
93, 108, 130, 107, \

106, 106, 101, 117, 93, 94,
103, 112, 98, 103, \
70, 139, 94, 110, 105, 122,
94, 94, 105, 129, \
110, 112, 97, 109, 121, 106,
118, 131, 88, 122, \
125, 93, 78]
group_b = [126, 89, 90, 101, 102, 74,
93, 101, 66, \
120, 108, 97, 98, 105, 119,
92, 113, 81, \
104, 108, 83, 102, 105, 111,
102, 107, 103, \
89, 89, 110, 71, 110, 120,
85, 111, 83, \
122, 120, 102, 84, 118, 100,
100, 114, 81, \
109, 69, 97, 95, 106, 116,
109, 114, 98, \
90, 92, 98, 91, 81, 85, 86,
102, 93, 112, \
76, 89, 110, 75, 100, 90, 96,
94, 107, 108, \
95, 96, 96, 114, 93, 95, 117,
141, 115, 95, \
86, 100, 121, 103, 66, 99,
96, 111, 110, 105, \
110, 91, 112, 102, 112, 75]
group_c = [108, 89, 114, 116, 126, 104,
113, 96, 69, 121, \
109, 102, 107, 122, 104, 107,
108, 137, 107, 116, \

98, 132, 108, 114, 82, 93,
89, 90, 86, 91, \
99, 98, 83, 93, 114, 96, 95,
113, 103, 81, \
107, 85, 116, 85, 107, 125,
126, 123, 122, 124, \
115, 114, 93, 93, 114, 107,
107, 84, 131, 91, \
108, 127, 112, 106, 115, 82,
90, 117, 108, 115, \
113, 108, 104, 103, 90, 110,
114, 92, 101, 72, \
109, 94, 122, 90, 102, 86,
119, 103, 110, 96, \
90, 110, 96, 69, 85, 102, 69,
96, 101, 90]
group_d = [93, 99, 91, 110, 80, 113,
111, 115, 98, 74, \
96, 80, 83, 102, 60, 91, 82,
90, 97, 101, \
89, 89, 117, 91, 104, 104,
102, 128, 106, 111, \
79, 92, 97, 101, 106, 110,
93, 93, 106, 108, \
85, 83, 108, 94, 79, 87, 113,
112, 111, 111, \
79, 116, 104, 84, 116, 111,
103, 103, 112, 68, \
54, 80, 86, 119, 81, 84, 91,
96, 116, 125, \
99, 58, 102, 77, 98, 100, 90,
106, 109, 114, \

102, 102, 112, 103, 98, 96,
85, 97, 110, 131, \
92, 79, 115, 122, 95, 105,
74, 85, 85, 95]

# %%
plt.boxplot([group_a,group_b,group_c,group_d],labels=['Group_a','Group_b','Group_c','Group_d'])
plt.ylabel('IQ Score')
plt.title('IQ SCores for a different test group')
# Out:
# Text(0.5, 1.0, 'IQ SCores for a different test group')

# %% [markdown]
# ## Excercise 8

# %%
anage = pd.read_csv("./Activity 8 (15 Oct 2022)/Datasets/anage_data.csv")
anage
# Out:
#       Unnamed: 0  HAGRID   Kingdom      Phylum                  Class  \
# 0              0       3  Animalia  Arthropoda           Branchiopoda
# 1              1       5  Animalia  Arthropoda                Insecta
# 2              2       6  Animalia  Arthropoda                Insecta
# 3              3       8  Animalia  Arthropoda                Insecta
# 4              4       9  Animalia  Arthropoda                Insecta
# ...          ...     ...       ...         ...                    ...
# 4213        4214    4239  Animalia    Porifera         Hexactinellida
# 4214        4215    4241   Plantae   Pinophyta              Pinopsida
# 4215        4216    4242     Fungi  Ascomycota        Saccharomycetes
# 4216        4217    4243     Fungi  Ascomycota  Schizosaccharomycetes
# 4217        4218    4244     Fungi  Ascomycota        Sordariomycetes
#
#                         Order                    Family                Genus  \
# ...

# %%
longevity = 'Maximum longevity (yrs)'
mass = 'Body mass (g)'
data = anage[np.isfinite(anage[longevity])
\
& np.isfinite(anage[mass])]
# Sort according to class
amphibia = data[data['Class'] ==
'Amphibia']
aves = data[data['Class'] == 'Aves']
mammalia = data[data['Class'] ==
'Mammalia']
reptilia = data[data['Class'] ==
'Reptilia']

# %%
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(amphibia[mass],amphibia[longevity], label='Amphibia')
plt.scatter(aves[mass], aves[longevity],label='Aves')
plt.scatter(mammalia[mass],mammalia[longevity], label='Mammalia')
plt.scatter(reptilia[mass],reptilia[longevity], label='Reptilia')
plt.legend()
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlabel('Body mass in grams')
plt.ylabel('Maximum longevity in years')
# Out:
# Text(0, 0.5, 'Maximum longevity in years')

# %% [markdown]
# ## Excercise 9

# %%
Attributes= ['Efficiency', 'Quality','Commitment', 'Responsible' ,'Conduct','Cooperation']

data = pd.DataFrame({'Employee': ['Alex',
'Alice', \
'Chris',
'Jennifer'], \
'Efficiency': [5, 4, 4,
3,],
'Quality': [5, 5, 3, 3],
'Commitment': [5, 4, 4,
4],
'Responsible Conduct': [4,
4, 4, 3],
'Cooperation': [4, 3, 4,
5]})

# %%
attributes = list(data.columns[1:])
values = list(data.values[:, 1:])
employees = list(data.values[:, 0])
angles = [n / float(len(attributes)) * 2
\
* np.pi for n in
range(len(attributes))]
# Close the plot
angles += angles[:1]
values = np.asarray(values)
values = np.concatenate([values,
values[:, 0:1]], axis=1)

# %%
# Create figure
plt.figure(figsize=(8, 8), dpi=150)
# Create subplots
for i in range(4):
    ax = plt.subplot(2, 2, i + 1,polar=True)
    ax.plot(angles, values[i])
ax.set_yticks([1, 2, 3, 4, 5])
ax.set_xticks(angles)
ax.set_xticklabels(attributes)
ax.set_title(employees[i],
fontsize=14, color='r')
# Set tight layout
plt.tight_layout()
# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_57107/175188252.py in <module>
#       7 ax.set_yticks([1, 2, 3, 4, 5])
#       8 ax.set_xticks(angles)
# ----> 9 ax.set_xticklabels(attributes)
#      10 ax.set_title(employees[i],
#      11 fontsize=14, color='r')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
# ...

# %%
small_aves = aves[aves['Body mass (g)']<20000]

# %%
small_aves
# Out:
#       Unnamed: 0  HAGRID   Kingdom    Phylum Class            Order  \
# 184          184     192  Animalia  Chordata  Aves  Accipitriformes
# 189          189     197  Animalia  Chordata  Aves  Accipitriformes
# 199          199     207  Animalia  Chordata  Aves  Accipitriformes
# 214          214     222  Animalia  Chordata  Aves  Accipitriformes
# 232          232     240  Animalia  Chordata  Aves  Accipitriformes
# ...          ...     ...       ...       ...   ...              ...
# 1342        1342    1351  Animalia  Chordata  Aves     Strigiformes
# 1348        1348    1357  Animalia  Chordata  Aves     Strigiformes
# 1354        1354    1363  Animalia  Chordata  Aves       Suliformes
# 1361        1361    1370  Animalia  Chordata  Aves       Suliformes
# 1368        1368    1377  Animalia  Chordata  Aves       Suliformes
#
#                  Family          Genus       Species  \
# 184        Accipitridae      Accipiter         nisus
# ...

# %%
plt.figure(figsize = (16,10))
from matplotlib.gridspec import GridSpec
gs = GridSpec(4, 4)
ax1 = plt.subplot(gs[0, 0:2])
ax2 = plt.subplot(gs[1:, 0:2])
ax3 = plt.subplot(gs[1:3,3])

ax2.scatter(small_aves['Body mass (g)'],small_aves['Maximum longevity (yrs)'])
ax2.bar(small_aves['Body mass (g)'],small_aves['Maximum longevity (yrs)'])
ax2.barh(small_aves['Body mass (g)'],small_aves['Maximum longevity (yrs)'])
# Out:
# <BarContainer object of 166 artists>

# %% [markdown]
# ## Excercise 10

# %%
import matplotlib.image as mpimg
import os
fig = plt.figure(figsize=(10,10))
img_filenames =os.listdir('./Activity 8 (15 Oct 2022)/Datasets/images')
imgs = [mpimg.imread(os.path.join('./Activity 8 (15 Oct 2022)/Datasets/images',img_filename)) for img_filename in img_filenames]
labels = ['coast', 'beach','building','city at night']
ax = []
for i in range(4):
    ax.append(fig.add_subplot(2,2,i+1))
    plt.imshow(imgs[i])
    ax[i].set_xticks([])
    ax[i].set_yticks([])
    ax[i].set_xlabel(labels[i])
